# %%
import pandas as pd

file_path="/jupiter/LolStats/LolStats_2025.csv"
df=pd.read_csv(file_path)

df.head(1)
# Out:
#   Unnamed: 0     id apiname             title  difficulty herotype alttype  \
# 0     Aatrox  266.0  Aatrox  the Darkin Blade           2  Fighter    Tank
#
#      resource                                              stats rangetype  \
# 0  Blood Well  {'hp_base': 650, 'hp_lvl': 114, 'mp_base': 0, ...     Melee
#
#    ...    be   rp                     skill_i  \
# 0  ...  4800  880  {1: 'Deathbringer Stance'}
#
#                                             skill_q                 skill_w  \
# 0  {1: 'The Darkin Blade', 2: 'The Darkin Blade 3'}  {1: 'Infernal Chains'}
#
#               skill_e             skill_r  \
# 0  {1: 'Umbral Dash'}  {1: 'World Ender'}
#
#                                               skills  fullname  nickname
# 0  {1: 'Deathbringer Stance', 2: 'The Darkin Blad...       NaN       NaN
#
# [1 rows x 33 columns]

# %%
print(df.dtypes)
# Out:
# Unnamed: 0             object
# id                    float64
# apiname                object
# title                  object
# difficulty              int64
# herotype               object
# alttype                object
# resource               object
# stats                  object
# rangetype              object
# date                   object
# patch                  object
# changes                object
# role                   object
# client_positions       object
# external_positions     object
# damage                  int64
# toughness               int64
# control                 int64
# mobility                int64
# utility                 int64
# style                   int64
# adaptivetype           object
# be                      int64
# rp                      int64
# skill_i                object
# skill_q                object
# skill_w                object
# skill_e                object
# skill_r                object
# skills                 object
# ...

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0              0
# id                      0
# apiname                 0
# title                   0
# difficulty              0
# herotype                0
# alttype                28
# resource                5
# stats                   0
# rangetype               0
# date                    0
# patch                   0
# changes                 0
# role                    0
# client_positions        0
# external_positions      0
# damage                  0
# toughness               0
# control                 0
# mobility                0
# utility                 0
# style                   0
# adaptivetype            0
# be                      0
# rp                      0
# skill_i                 0
# skill_q                 0
# skill_w                 0
# skill_e                 0
# skill_r                 0
# skills                  2
# fullname              129
# nickname              158
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.countplot(data=df,x="difficulty")
plt.title("Champion difficulty")
plt.ylabel("count")
plt.xlabel("Difficulty")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x="rangetype",order=df['rangetype'].value_counts().index)
plt.title("Range type")
plt.ylabel("count")
plt.xlabel("Range type")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.sort_values('herotype')
plt.figure(figsize=(8,5))
sns.countplot(data=df,x="herotype",order=df['herotype'].value_counts().index)
plt.title("Hero type")
plt.ylabel("count")
plt.xlabel("Hero type")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.sort_values('resource')
plt.figure(figsize=(12,7))
sns.countplot(data=df,x="resource",order=df['resource'].value_counts().index)
plt.title("Resource")
plt.ylabel("Count")
plt.xlabel("Resource")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.sort_values('herotype')
plt.figure(figsize=(12,7))
sns.countplot(data=df,x="herotype",order=df['herotype'].value_counts().index)
plt.title("Resource")
plt.ylabel("Count")
plt.xlabel("Herotype")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.sort_values('role')
plt.figure(figsize=(20,20))
plt.xticks(rotation=90)
sns.countplot(data=df,x="role",order=df['role'].value_counts().index)
plt.title("Role")
plt.ylabel("Count")
plt.xlabel("Role")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
